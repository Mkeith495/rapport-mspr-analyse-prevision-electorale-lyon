# %%
import pandas as pd

# %%
df = pd.read_csv('data/raw/inscrits_chomage.csv', sep=';')
df.head()
# Out:
# /var/folders/c_/jwr8r3jj0q97qpmmg4kqmt5h0000gn/T/ipykernel_17514/714804868.py:1: DtypeWarning: Columns (0: Code région) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/raw/inscrits_chomage.csv', sep=';')
#       Date Code région     Région Code département Département Code commune  \
# 0  2015-T4          44  Grand-Est               88      Vosges        88083
# 1  2015-T4          44  Grand-Est               88      Vosges        88083
# 2  2015-T4          44  Grand-Est               88      Vosges        88084
# 3  2015-T4          44  Grand-Est               88      Vosges        88084
# 4  2015-T4          44  Grand-Est               88      Vosges        88084
#
#       Commune Type de données Catégorie   Sexe    Tranche d'âge  \
# 0  Certilleux          Brutes       ABC  Total  Moins de 25 ans
# 1  Certilleux          Brutes       ABC  Total   50 ans et plus
# 2    Chamagne          Brutes       ABC  Total            Total
# ...
